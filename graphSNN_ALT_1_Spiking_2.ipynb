# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import haversine_distances
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv

# %%
# Loading telecom dataset
telecom_data = pd.read_csv('cellular_dataframe.csv')

# remove nan values in latitudes and longitudes in telecom_data
telecom_data = telecom_data[~np.isnan(telecom_data['Latitude'])]
telecom_data = telecom_data[~np.isnan(telecom_data['Longitude'])]
#remove nan values in PCell_Downlink_Num_RBs, PCell_Downlink_TB_Size, SCell_Downlink_TB_Size and datarate
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_Downlink_Num_RBs'])]
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_Downlink_TB_Size'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_TB_Size'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_Num_RBs'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_RBs_MCS_28'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_RBs_MCS_31'])]
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_RSRP_max'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_RSRP_max'])]
telecom_data = telecom_data[~np.isnan(telecom_data['datarate'])]

# # selecting a random 10000 rows from the dataset
# telecom_data = telecom_data.sample(n=20000, random_state=42)
#normalizing the datarate using min-max normalization
telecom_data['datarate'] = ((np.max(telecom_data['datarate'])-telecom_data['datarate'])*100)/(np.max(telecom_data['datarate'])-np.min(telecom_data['datarate']))

#splitting the dataset into train and test sets
train_data, test_data = train_test_split(telecom_data, test_size=0.2, random_state=42)

telecom_data = train_data

print(telecom_data.shape)
print(test_data.shape)

# Extract relevant features and labels
features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
# # normalizing the labels using min-max normalization
# labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))

 
# Extract latitudes and longitudes
latitudes = telecom_data['Latitude'].values
longitudes = telecom_data['Longitude'].values
# Out:
# (3319, 159)
# (664, 159)

# %%
# finding min and max values of labels
print(np.min(labels), np.max(labels))
# Out:
# 0.0 100.0

# %%
# Calculate pairwise distances using Haversine formula
coordinates = np.column_stack((latitudes, longitudes))
dist_matrix = haversine_distances(np.radians(coordinates))

# Define distance threshold for edges
distance_threshold = 1 # For example, consider nodes within 1 km as neighbors

# %%
# Create adjacency matrix based on distance threshold
adj_matrix = (dist_matrix <= distance_threshold).astype(int)

# Convert adjacency matrix to edge indices
edge_indices = np.transpose(np.nonzero(adj_matrix))
edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()

# %%
adj_matrix.shape
# Out:
# (3319, 3319)

# %%
# count the number of edges
np.count_nonzero(adj_matrix)
# Out:
# 11015761

# %%
# Split data into train and test sets
X_train, y_train = features,labels
y_train= y_train.reshape(-1,1)

# %%
X_train.shape
# Out:
# (3319, 8)

# %%
# Convert data to tensors
x = torch.FloatTensor(X_train)
y = torch.FloatTensor(y_train)

# %%
# Create a graph data object using torch_geometric
data = Data(x=x, edge_index=edge_indices, y=y)

# %%
from torch_geometric.nn import SAGEConv
import pytorch_spiking

class ComplexGNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(ComplexGNN, self).__init__()
        self.conv1 = SAGEConv(input_dim, hidden_dim)
        self.conv2 = SAGEConv(hidden_dim, hidden_dim)
        self.conv3 = SAGEConv(hidden_dim, hidden_dim)
        self.conv4 = SAGEConv(hidden_dim, hidden_dim)
        self.conv5 = SAGEConv(hidden_dim, hidden_dim)
        self.conv6 = SAGEConv(hidden_dim, hidden_dim)
        self.linear1 = nn.Linear(hidden_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(0.5)  # Adding dropout for regularization

        # Defining the spiking activation
        self.spiking_activation = pytorch_spiking.SpikingActivation(torch.nn.ReLU(),dt=0.1)
    
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension
        x = self.dropout(x)

        x = self.conv2(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension
        x = self.dropout(x)

        x = self.conv3(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension

        x = self.conv4(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension
        x = self.dropout(x)

        x = self.conv5(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension

        x = self.conv6(x, edge_index)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension
        
        x = self.linear1(x)
        x = x.unsqueeze(2)  # Add a dummy dimension
        x = self.spiking_activation(x)
        x = x.squeeze(2)  # Remove the dummy dimension
        
        x = self.linear2(x)

        return x

# %%
# Define your loss function and optimizer
gnn_model = ComplexGNN(input_dim=features.shape[1], hidden_dim=16, output_dim=1)
# # loading a pytorch model from a saved state dict
# gnn_model.load_state_dict(torch.load('lat_long_node_GNN_rsrp_spiking.pth'))
loss_function = nn.MSELoss()  # For regression tasks
optimizer = optim.Adam(gnn_model.parameters(), lr=0.001)

# Create a DataLoader for batching your data
dataloader = DataLoader([data], batch_size=200)

# %%
# # loading training and validation loss from a pickle file
# import pickle
# with open('lat_long_node_GNN_rsrp_spiking.pkl', 'rb') as f:
#     training_acc, validation_acc = pickle.load(f)

# %%
training_acc = []
validation_acc = []

# %%
def get_validation(test_data):
    telecom_data = test_data
    # Extract relevant features and labels
    features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
    labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
    # # normalizing the labels using min-max normalization
    # labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))
    
     
    # Extract latitudes and longitudes
    latitudes = telecom_data['Latitude'].values
    longitudes = telecom_data['Longitude'].values
    
    # Calculate pairwise distances using Haversine formula
    coordinates = np.column_stack((latitudes, longitudes))
    dist_matrix = haversine_distances(np.radians(coordinates))
    
    # Define distance threshold for edges
    distance_threshold = 1  # For example, consider nodes within 10 km as neighbors
    
    # Create adjacency matrix based on distance threshold
    adj_matrix = (dist_matrix <= distance_threshold).astype(int)
    
    # Convert adjacency matrix to edge indices
    edge_indices = np.transpose(np.nonzero(adj_matrix))
    edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    
    loss_function = nn.MSELoss()
    
    X_train, y_train = features,labels
    y_train= y_train.reshape(-1,1)
    # Convert data to tensors
    x = torch.FloatTensor(X_train)
    y = torch.FloatTensor(y_train)
    # Create a graph data object using torch_geometric
    data = Data(x=x, edge_index=edge_indices, y=y)
    dataloader = DataLoader([data], batch_size=664)
    # Evaluation on test set
    gnn_model.eval()
    with torch.no_grad():
        for batch_data in dataloader:
            #print(batch_data.x.shape, batch_data.edge_index.shape, batch_data.y.shape)
            output = gnn_model(batch_data.x, batch_data.edge_index)
            loss = loss_function(output, batch_data.y)
            # print(f"Epoch [{epoch + 1}/{num_epochs}], Batch Loss: {(loss.item()):.4f}")
            #print mape using sklearn
            return loss.item()

# %%
# Training loop
num_epochs = 1000

for epoch in range(num_epochs):
    #setting best validation loss to infinity
    best_val_loss = np.inf
    for batch_data in dataloader:
        optimizer.zero_grad()
        # print(batch_data.x.shape, batch_data.edge_index.shape, batch_data.y.shape)
        output = gnn_model(batch_data.x, batch_data.edge_index)
        loss = loss_function(output, batch_data.y)
        loss.backward()
        optimizer.step()
        print(f"Epoch [{epoch + 1}/{num_epochs}], Batch Loss: {(loss.item()):.4f}")
        val_loss = get_validation(test_data)
        print(f"Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {(val_loss):.4f}")
        print("--------------------------------------------------")
        training_acc.append(loss.item())
        validation_acc.append(val_loss)
        # saving the model with best validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(gnn_model.state_dict(), 'lat_long_node_GNN_rsrp_spiking_best.pth')
# Out:
# Epoch [1/1000], Batch Loss: 99.5800
# Epoch [1/1000], Validation Loss: 110.8355
# --------------------------------------------------
# Epoch [2/1000], Batch Loss: 99.2428
# Epoch [2/1000], Validation Loss: 108.6410
# --------------------------------------------------
# Epoch [3/1000], Batch Loss: 100.7994
# Epoch [3/1000], Validation Loss: 107.5257
# --------------------------------------------------
# Epoch [4/1000], Batch Loss: 100.5765
# Epoch [4/1000], Validation Loss: 107.2432
# --------------------------------------------------
# Epoch [5/1000], Batch Loss: 99.9075
# Epoch [5/1000], Validation Loss: 108.0723
# --------------------------------------------------
# Epoch [6/1000], Batch Loss: 99.1928
# Epoch [6/1000], Validation Loss: 109.6905
# --------------------------------------------------
# Epoch [7/1000], Batch Loss: 98.0601
# Epoch [7/1000], Validation Loss: 108.8204
# --------------------------------------------------
# Epoch [8/1000], Batch Loss: 99.0181
# Epoch [8/1000], Validation Loss: 106.9845
# --------------------------------------------------
# Epoch [9/1000], Batch Loss: 99.5902
# Epoch [9/1000], Validation Loss: 107.2219
# --------------------------------------------------
# Epoch [10/1000], Batch Loss: 99.2972
# Epoch [10/1000], Validation Loss: 107.3793
# --------------------------------------------------
# Epoch [11/1000], Batch Loss: 100.8508
# Epoch [11/1000], Validation Loss: 105.5469
# --------------------------------------------------
# Epoch [12/1000], Batch Loss: 99.3896
# Epoch [12/1000], Validation Loss: 106.8161
# --------------------------------------------------
# Epoch [13/1000], Batch Loss: 99.8443
# Epoch [13/1000], Validation Loss: 107.1831
# --------------------------------------------------
# Epoch [14/1000], Batch Loss: 99.9519
# Epoch [14/1000], Validation Loss: 106.8657
# --------------------------------------------------
# Epoch [15/1000], Batch Loss: 99.9900
# Epoch [15/1000], Validation Loss: 107.2935
# --------------------------------------------------
# Epoch [16/1000], Batch Loss: 99.5683
# Epoch [16/1000], Validation Loss: 106.9545
# --------------------------------------------------
# Epoch [17/1000], Batch Loss: 99.7876
# Epoch [17/1000], Validation Loss: 107.2453
# --------------------------------------------------
# Epoch [18/1000], Batch Loss: 98.8171
# Epoch [18/1000], Validation Loss: 107.5415
# --------------------------------------------------
# Epoch [19/1000], Batch Loss: 98.6352
# Epoch [19/1000], Validation Loss: 108.0072
# --------------------------------------------------
# Epoch [20/1000], Batch Loss: 99.2329
# Epoch [20/1000], Validation Loss: 106.9885
# --------------------------------------------------
# Epoch [21/1000], Batch Loss: 99.0620
# Epoch [21/1000], Validation Loss: 105.7708
# --------------------------------------------------
# Epoch [22/1000], Batch Loss: 98.9938
# Epoch [22/1000], Validation Loss: 107.1369
# --------------------------------------------------
# Epoch [23/1000], Batch Loss: 98.9040
# Epoch [23/1000], Validation Loss: 107.3644
# --------------------------------------------------
# Epoch [24/1000], Batch Loss: 98.6691
# Epoch [24/1000], Validation Loss: 106.3135
# --------------------------------------------------
# Epoch [25/1000], Batch Loss: 99.8726
# Epoch [25/1000], Validation Loss: 108.3872
# --------------------------------------------------
# Epoch [26/1000], Batch Loss: 98.7936
# Epoch [26/1000], Validation Loss: 109.5035
# --------------------------------------------------
# Epoch [27/1000], Batch Loss: 99.4888
# Epoch [27/1000], Validation Loss: 108.7440
# --------------------------------------------------
# Epoch [28/1000], Batch Loss: 100.2826
# Epoch [28/1000], Validation Loss: 108.8256
# --------------------------------------------------
# Epoch [29/1000], Batch Loss: 99.3830
# Epoch [29/1000], Validation Loss: 108.4517
# --------------------------------------------------
# Epoch [30/1000], Batch Loss: 100.0831
# Epoch [30/1000], Validation Loss: 105.5957
# --------------------------------------------------
# Epoch [31/1000], Batch Loss: 97.4779
# Epoch [31/1000], Validation Loss: 106.6574
# --------------------------------------------------
# Epoch [32/1000], Batch Loss: 99.3086
# Epoch [32/1000], Validation Loss: 106.9943
# --------------------------------------------------
# Epoch [33/1000], Batch Loss: 99.4579
# Epoch [33/1000], Validation Loss: 103.8657
# --------------------------------------------------
# Epoch [34/1000], Batch Loss: 98.7724
# Epoch [34/1000], Validation Loss: 109.0394
# --------------------------------------------------
# Epoch [35/1000], Batch Loss: 98.3781
# Epoch [35/1000], Validation Loss: 106.6502
# --------------------------------------------------
# Epoch [36/1000], Batch Loss: 98.3944
# Epoch [36/1000], Validation Loss: 104.3067
# --------------------------------------------------
# Epoch [37/1000], Batch Loss: 99.6461
# Epoch [37/1000], Validation Loss: 109.0046
# --------------------------------------------------
# Epoch [38/1000], Batch Loss: 98.0494
# Epoch [38/1000], Validation Loss: 109.1903
# --------------------------------------------------
# Epoch [39/1000], Batch Loss: 98.6760
# Epoch [39/1000], Validation Loss: 104.4347
# --------------------------------------------------
# Epoch [40/1000], Batch Loss: 99.0681
# Epoch [40/1000], Validation Loss: 105.9642
# --------------------------------------------------
# Epoch [41/1000], Batch Loss: 97.8911
# Epoch [41/1000], Validation Loss: 108.7236
# --------------------------------------------------
# Epoch [42/1000], Batch Loss: 99.5905
# Epoch [42/1000], Validation Loss: 103.5648
# --------------------------------------------------
# Epoch [43/1000], Batch Loss: 98.2055
# Epoch [43/1000], Validation Loss: 110.6936
# --------------------------------------------------
# Epoch [44/1000], Batch Loss: 98.5882
# Epoch [44/1000], Validation Loss: 107.6908
# --------------------------------------------------
# Epoch [45/1000], Batch Loss: 99.4848
# Epoch [45/1000], Validation Loss: 107.2595
# --------------------------------------------------
# Epoch [46/1000], Batch Loss: 98.7700
# Epoch [46/1000], Validation Loss: 109.0605
# --------------------------------------------------
# Epoch [47/1000], Batch Loss: 98.4039
# Epoch [47/1000], Validation Loss: 109.6736
# --------------------------------------------------
# Epoch [48/1000], Batch Loss: 99.3749
# Epoch [48/1000], Validation Loss: 106.1913
# --------------------------------------------------
# Epoch [49/1000], Batch Loss: 98.3600
# Epoch [49/1000], Validation Loss: 103.8894
# --------------------------------------------------
# Epoch [50/1000], Batch Loss: 99.4877
# Epoch [50/1000], Validation Loss: 109.4587
# --------------------------------------------------
# Epoch [51/1000], Batch Loss: 99.2384
# Epoch [51/1000], Validation Loss: 106.3001
# --------------------------------------------------
# Epoch [52/1000], Batch Loss: 97.7107
# Epoch [52/1000], Validation Loss: 107.4780
# --------------------------------------------------
# Epoch [53/1000], Batch Loss: 98.9442
# Epoch [53/1000], Validation Loss: 103.6310
# --------------------------------------------------
# Epoch [54/1000], Batch Loss: 98.6695
# Epoch [54/1000], Validation Loss: 108.1010
# --------------------------------------------------
# Epoch [55/1000], Batch Loss: 99.1498
# Epoch [55/1000], Validation Loss: 110.4296
# --------------------------------------------------
# Epoch [56/1000], Batch Loss: 97.4964
# Epoch [56/1000], Validation Loss: 108.5809
# --------------------------------------------------
# Epoch [57/1000], Batch Loss: 98.7526
# Epoch [57/1000], Validation Loss: 106.6815
# --------------------------------------------------
# Epoch [58/1000], Batch Loss: 97.6268
# Epoch [58/1000], Validation Loss: 103.7654
# --------------------------------------------------
# Epoch [59/1000], Batch Loss: 98.9662
# Epoch [59/1000], Validation Loss: 107.5748
# --------------------------------------------------
# Epoch [60/1000], Batch Loss: 98.7212
# Epoch [60/1000], Validation Loss: 105.9047
# --------------------------------------------------
# Epoch [61/1000], Batch Loss: 99.0315
# Epoch [61/1000], Validation Loss: 107.5824
# --------------------------------------------------
# Epoch [62/1000], Batch Loss: 99.2330
# Epoch [62/1000], Validation Loss: 105.8046
# --------------------------------------------------
# Epoch [63/1000], Batch Loss: 98.0854
# Epoch [63/1000], Validation Loss: 105.0492
# --------------------------------------------------
# Epoch [64/1000], Batch Loss: 98.5275
# Epoch [64/1000], Validation Loss: 104.4999
# --------------------------------------------------
# Epoch [65/1000], Batch Loss: 98.1065
# Epoch [65/1000], Validation Loss: 106.5223
# --------------------------------------------------
# Epoch [66/1000], Batch Loss: 98.9408
# Epoch [66/1000], Validation Loss: 106.4232
# --------------------------------------------------
# Epoch [67/1000], Batch Loss: 97.8101
# Epoch [67/1000], Validation Loss: 104.7045
# --------------------------------------------------
# Epoch [68/1000], Batch Loss: 98.2475
# Epoch [68/1000], Validation Loss: 105.7997
# --------------------------------------------------

# %%
# plot training and validation loss
import matplotlib.pyplot as plt
plt.plot(training_acc, label='Training loss')
plt.plot(validation_acc, label='Validation loss')
plt.legend()
plt.show()

# %%
print(min(validation_acc))
# 89.89
# Out:
# 82.332275390625

# %%
len(validation_acc)
# Out:
# 8000

# %%
# print last 10 validation losses
print(validation_acc[-100:])
# Out:
# [90.25334930419922, 88.5505142211914, 87.63139343261719, 87.3066635131836, 88.60247802734375, 86.16129302978516, 88.67098999023438, 86.09484100341797, 88.38377380371094, 87.3938217163086, 86.51296997070312, 85.82942199707031, 85.8031005859375, 86.54318237304688, 87.84183502197266, 90.85400390625, 87.3396224975586, 87.38410949707031, 85.98375701904297, 84.3191146850586, 88.575439453125, 86.84466552734375, 89.15631103515625, 85.95929718017578, 84.1384506225586, 84.51542663574219, 86.81652069091797, 89.70099639892578, 86.13388061523438, 87.99203491210938, 86.08554077148438, 85.39020538330078, 87.07389068603516, 87.90162658691406, 84.36145782470703, 88.82559967041016, 86.01966857910156, 87.24775695800781, 85.3617172241211, 87.48590850830078, 88.25421905517578, 86.74718475341797, 85.99500274658203, 86.35236358642578, 85.8949966430664, 87.22938537597656, 86.4119873046875, 82.332275390625, 85.58155059814453, 86.68164825439453, 87.26866149902344, 86.78034973144531, 88.36884307861328, 85.41046905517578, 87.30697631835938, 88.84124755859375, 86.84275817871094, 85.38978576660156, 85.88221740722656, 87.45079803466797, 85.13636016845703, 88.38259887695312, 85.14080047607422, 85.11553955078125, 86.751220703125, 86.03270721435547, 86.03434753417969, 88.11173248291016, 85.58016967773438, 86.25173950195312, 88.16060638427734, 86.57479095458984, 86.69314575195312, 86.78727722167969, 86.19976806640625, 84.24078369140625, 88.87478637695312, 86.3310546875, 86.96847534179688, 86.78877258300781, 87.23017120361328, 87.23188018798828, 86.20516967773438, 85.21394348144531, 84.78611755371094, 87.43270874023438, 83.56169128417969, 86.7362289428711, 83.3440170288086, 85.35220336914062, 83.60159301757812, 85.423828125, 84.5544204711914, 86.46781921386719, 86.18049621582031, 83.49463653564453, 85.82938385009766, 82.48554992675781, 87.3623275756836, 84.47284698486328]

# %%
# saving the model
torch.save(gnn_model.state_dict(), 'lat_long_node_GNN_rsrp_spiking.pth')

# %%
# saving the validation loss and training loss as a pickle file
import pickle
with open('lat_long_node_GNN_rsrp_spiking.pkl', 'wb') as f:
    pickle.dump([training_acc, validation_acc], f)

# %%
def evaluate_model(telecom_data):
    # Extract relevant features and labels
    features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
    labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
    
    # # Normalizing the labels using min-max normalization
    # labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))
    
    # Extract latitudes and longitudes
    latitudes = telecom_data['Latitude'].values
    longitudes = telecom_data['Longitude'].values
    
    # Calculate pairwise distances using Haversine formula
    coordinates = np.column_stack((latitudes, longitudes))
    dist_matrix = haversine_distances(np.radians(coordinates))
    
    # Define distance threshold for edges
    distance_threshold = 1  # Consider nodes within specified distance as neighbors
    
    # Create adjacency matrix based on distance threshold
    adj_matrix = (dist_matrix <= distance_threshold).astype(int)
    
    # Convert adjacency matrix to edge indices
    edge_indices = np.transpose(np.nonzero(adj_matrix))
    edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    
    loss_function = nn.MSELoss()
    
    X_train, y_train = features,labels
    y_train= y_train.reshape(-1,1)
    
    # Convert data to tensors
    x = torch.FloatTensor(X_train)
    y = torch.FloatTensor(y_train)
    
    # Create a graph data object using torch_geometric
    data = Data(x=x, edge_index=edge_indices, y=y)
    dataloader = DataLoader([data], batch_size=664)
    
    # Evaluation on test set
    gnn_model.eval()
    
    true_labels = []
    predicted_labels = []
    
    with torch.no_grad():
        for batch_data in dataloader:
            output = gnn_model(batch_data.x, batch_data.edge_index)
            
            true_labels.extend(batch_data.y.numpy())
            predicted_labels.extend(output.numpy())

    return true_labels, predicted_labels

# %%
a,b = evaluate_model(telecom_data=test_data)

# %%
print(a)
# Out:
# [array([68.69766], dtype=float32), array([64.0784], dtype=float32), array([48.409866], dtype=float32), array([68.25421], dtype=float32), array([85.84436], dtype=float32), array([52.105274], dtype=float32), array([52.844357], dtype=float32), array([49.14895], dtype=float32), array([73.464745], dtype=float32), array([48.409866], dtype=float32), array([66.7391], dtype=float32), array([81.705505], dtype=float32), array([35.10639], dtype=float32), array([41.75813], dtype=float32), array([49.888027], dtype=float32), array([73.68647], dtype=float32), array([30.302359], dtype=float32), array([65.076164], dtype=float32), array([61.3438], dtype=float32), array([92.0157], dtype=float32), array([28.824194], dtype=float32), array([30.6719], dtype=float32), array([60.604717], dtype=float32), array([57.278847], dtype=float32), array([77.75142], dtype=float32), array([42.866753], dtype=float32), array([74.092964], dtype=float32), array([90.35276], dtype=float32), array([60.235176], dtype=float32), array([50.99665], dtype=float32), array([68.06944], dtype=float32), array([77.52969], dtype=float32), array([48.409866], dtype=float32), array([79.562164], dtype=float32), array([74.90595], dtype=float32), array([61.3438], dtype=float32), array([48.409866], dtype=float32), array([67.58904], dtype=float32), array([66.29565], dtype=float32), array([4.4344916], dtype=float32), array([57.278847], dtype=float32), array([76.97538], dtype=float32), array([68.06944], dtype=float32), array([70.24973], dtype=float32), array([60.97426], dtype=float32), array([70.10192], dtype=float32), array([64.52185], dtype=float32), array([29.932817], dtype=float32), array([55.061604], dtype=float32), array([70.54537], dtype=float32), array([58.01793], dtype=float32), array([73.27997], dtype=float32), array([42.12767], dtype=float32), array([41.019047], dtype=float32), array([58.01793], dtype=float32), array([61.71334], dtype=float32), array([64.70662], dtype=float32), array([50.99665], dtype=float32), array([87.618164], dtype=float32), array([78.896996], dtype=float32), array([38.062717], dtype=float32), array([81.409874], dtype=float32), array([28.454653], dtype=float32), array([34.36731], dtype=float32), array([73.316925], dtype=float32), array([48.040325], dtype=float32), array([33.258686], dtype=float32), array([48.779408], dtype=float32), array([63.450184], dtype=float32), array([76.716705], dtype=float32), array([67.44122], dtype=float32), array([30.6719], dtype=float32), array([45.083996], dtype=float32), array([40.649506], dtype=float32), array([25.128784], dtype=float32), array([73.61256], dtype=float32), array([68.77157], dtype=float32), array([33.99777], dtype=float32), array([33.99777], dtype=float32), array([49.888027], dtype=float32), array([51.36619], dtype=float32), array([36.954094], dtype=float32), array([76.088486], dtype=float32), array([63.1915], dtype=float32), array([76.60584], dtype=float32), array([45.083996], dtype=float32), array([68.54985], dtype=float32), array([59.496094], dtype=float32), array([63.598], dtype=float32), array([86.28781], dtype=float32), array([73.42779], dtype=float32), array([52.844357], dtype=float32), array([15.5207205], dtype=float32), array([71.94962], dtype=float32), array([76.45802], dtype=float32), array([47.301243], dtype=float32), array([55.061604], dtype=float32), array([71.21054], dtype=float32), array([76.753654], dtype=float32), array([76.753654], dtype=float32), array([36.584553], dtype=float32), array([82.62936], dtype=float32), array([85.36396], dtype=float32), array([48.409866], dtype=float32), array([43.60583], dtype=float32), array([64.18926], dtype=float32), array([63.1915], dtype=float32), array([76.31021], dtype=float32), array([48.779408], dtype=float32), array([32.889145], dtype=float32), array([45.083996], dtype=float32), array([83.55321], dtype=float32), array([39.17134], dtype=float32), array([60.235176], dtype=float32), array([85.142235], dtype=float32), array([60.97426], dtype=float32), array([76. ...

# %%
print(b)
# Out:
# [array([62.36409], dtype=float32), array([62.911453], dtype=float32), array([43.472], dtype=float32), array([64.541824], dtype=float32), array([83.34456], dtype=float32), array([55.88069], dtype=float32), array([59.930984], dtype=float32), array([44.124344], dtype=float32), array([83.62581], dtype=float32), array([59.223953], dtype=float32), array([70.39485], dtype=float32), array([82.63704], dtype=float32), array([32.17122], dtype=float32), array([34.63655], dtype=float32), array([59.85286], dtype=float32), array([67.109695], dtype=float32), array([38.20784], dtype=float32), array([60.535965], dtype=float32), array([59.94026], dtype=float32), array([74.371414], dtype=float32), array([45.148758], dtype=float32), array([25.86653], dtype=float32), array([61.96028], dtype=float32), array([45.86116], dtype=float32), array([62.309402], dtype=float32), array([51.745438], dtype=float32), array([86.379715], dtype=float32), array([93.02669], dtype=float32), array([39.302567], dtype=float32), array([41.860672], dtype=float32), array([59.80403], dtype=float32), array([69.89729], dtype=float32), array([58.124344], dtype=float32), array([77.17415], dtype=float32), array([57.794266], dtype=float32), array([45.965652], dtype=float32), array([46.30452], dtype=float32), array([65.132645], dtype=float32), array([64.03548], dtype=float32), array([19.992018], dtype=float32), array([39.891434], dtype=float32), array([65.268875], dtype=float32), array([61.257645], dtype=float32), array([85.84944], dtype=float32), array([49.24446], dtype=float32), array([65.38118], dtype=float32), array([59.635086], dtype=float32), array([26.337233], dtype=float32), array([36.255203], dtype=float32), array([69.20149], dtype=float32), array([45.738113], dtype=float32), array([71.09749], dtype=float32), array([44.12776], dtype=float32), array([42.525223], dtype=float32), array([39.83528], dtype=float32), array([50.973953], dtype=float32), array([64.13948], dtype=float32), array([61.94319], dtype=float32), array([87.655594], dtype=float32), array([64.34651], dtype=float32), array([25.710768], dtype=float32), array([74.23909], dtype=float32), array([26.200514], dtype=float32), array([38.63997], dtype=float32), array([63.34651], dtype=float32), array([30.79231], dtype=float32), array([14.336256], dtype=float32), array([59.01448], dtype=float32), array([63.870438], dtype=float32), array([75.6805], dtype=float32), array([63.465164], dtype=float32), array([40.275223], dtype=float32), array([40.512527], dtype=float32), array([32.788406], dtype=float32), array([36.5345], dtype=float32), array([62.714676], dtype=float32), array([67.936844], dtype=float32), array([31.4886], dtype=float32), array([43.928543], dtype=float32), array([59.30403], dtype=float32), array([60.96956], dtype=float32), array([39.464676], dtype=float32), array([66.54671], dtype=float32), array([63.83821], dtype=float32), array([63.30745], dtype=float32), array([48.865555], dtype=float32), array([67.53401], dtype=float32), array([56.97786], dtype=float32), array([64.69905], dtype=float32), array([78.21712], dtype=float32), array([71.52083], dtype=float32), array([35.27083], dtype=float32), array([23.163893], dtype=float32), array([59.984695], dtype=float32), array([66.84993], dtype=float32), array([43.877274], dtype=float32), array([62.084793], dtype=float32), array([58.206375], dtype=float32), array([68.331375], dtype=float32), array([72.6263], dtype=float32), array([47.63997], dtype=float32), array([80.89583], dtype=float32), array([80.99983], dtype=float32), array([50.830887], dtype=float32), array([40.91536], dtype=float32), array([57.623367], dtype=float32), array([62.22151], dtype=float32), array([67.703445], dtype=float32), array([45.31282], dtype=float32), array([31.956861], dtype=float32), array([47.464676], dtype=float32), array([82.172195], dtype=float32), array([44.23958], dtype=float32), array([58.81038], dtype=float32), array([62.476395], dtype=float32), array([56.27278], dtype=float32), array( ...

# %%
# plotting the graph for a and b
import matplotlib.pyplot as plt
plt.plot(a, label='True labels')
plt.plot(b, label='Predicted labels')
plt.legend()
plt.show()

# %%
# displaying the true and predicted labels in different graphs
import matplotlib.pyplot as plt
plt.plot(a, label='True labels')
plt.legend()
plt.show()

# %%
plt.plot(b, label='Predicted labels')
plt.legend()
plt.show()

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error
mean_absolute_error(a,b)
# Out:
# 6.623847

# %%
# calculating the mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(a,b)
# Out:
# 87.57329

# %%
# calculating the root mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(a,b, squared=False)
# Out:
# 9.35806

# %%
# calculating the r2 score
from sklearn.metrics import r2_score
r2_score(a,b)
# Out:
# 0.7488279062175216

# %%
# printing the mean absolute percentage error using sklearn
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(a,b)
# Out:
# 0.1611617
