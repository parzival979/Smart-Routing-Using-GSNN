# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import haversine_distances
import torch
import torch.nn as nn
import torch.optim as optim
from torch_geometric.data import Data
from torch_geometric.loader import DataLoader
from torch_geometric.nn import GCNConv

# %%
# Loading telecom dataset
telecom_data = pd.read_csv('cellular_dataframe.csv')

# remove nan values in latitudes and longitudes in telecom_data
telecom_data = telecom_data[~np.isnan(telecom_data['Latitude'])]
telecom_data = telecom_data[~np.isnan(telecom_data['Longitude'])]
#remove nan values in PCell_Downlink_Num_RBs, PCell_Downlink_TB_Size, SCell_Downlink_TB_Size and datarate
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_Downlink_Num_RBs'])]
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_Downlink_TB_Size'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_TB_Size'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_Num_RBs'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_RBs_MCS_28'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_Downlink_RBs_MCS_31'])]
telecom_data = telecom_data[~np.isnan(telecom_data['PCell_RSRP_max'])]
telecom_data = telecom_data[~np.isnan(telecom_data['SCell_RSRP_max'])]
telecom_data = telecom_data[~np.isnan(telecom_data['datarate'])]
telecom_data['datarate'] = ((np.max(telecom_data['datarate'])-telecom_data['datarate'])*100)/(np.max(telecom_data['datarate'])-np.min(telecom_data['datarate']))
# # selecting a random 10000 rows from the dataset
# telecom_data = telecom_data.sample(n=20000, random_state=42)

#splitting the dataset into train and test sets
train_data, test_data = train_test_split(telecom_data, test_size=0.2, random_state=42)

telecom_data = train_data

print(telecom_data.shape)
print(test_data.shape)

# Extract relevant features and labels
features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
# # normalizing the labels using min-max normalization
# labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))

 
# Extract latitudes and longitudes
latitudes = telecom_data['Latitude'].values
longitudes = telecom_data['Longitude'].values
# Out:
# (3319, 159)
# (664, 159)

# %%
# finding min and max values of labels
print(np.min(labels), np.max(labels))
# Out:
# 0.0 100.0

# %%
# Calculate pairwise distances using Haversine formula
coordinates = np.column_stack((latitudes, longitudes))
dist_matrix = haversine_distances(np.radians(coordinates))

# Define distance threshold for edges
distance_threshold = 1  # For example, consider nodes within 1 km as neighbors

# %%
# Create adjacency matrix based on distance threshold
adj_matrix = (dist_matrix <= distance_threshold).astype(int)

# Convert adjacency matrix to edge indices
edge_indices = np.transpose(np.nonzero(adj_matrix))
edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()

# %%
# Split data into train and test sets
X_train, y_train = features,labels
y_train= y_train.reshape(-1,1)

# %%
X_train.shape
# Out:
# (3319, 8)

# %%
# Convert data to tensors
x = torch.FloatTensor(X_train)
y = torch.FloatTensor(y_train)

# %%
# Create a graph data object using torch_geometric
data = Data(x=x, edge_index=edge_indices, y=y)

# %%
from torch_geometric.nn import SAGEConv

class ComplexGNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(ComplexGNN, self).__init__()
        self.conv1 = SAGEConv(input_dim, hidden_dim)
        self.conv2 = SAGEConv(hidden_dim, hidden_dim)
        self.conv3 = SAGEConv(hidden_dim, hidden_dim)
        self.conv4 = SAGEConv(hidden_dim, hidden_dim)
        self.conv5 = SAGEConv(hidden_dim, hidden_dim)
        self.conv6 = SAGEConv(hidden_dim, hidden_dim)
        self.linear1 = nn.Linear(hidden_dim, hidden_dim)
        self.linear2 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(0.5)  # Adding dropout for regularization
    
    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.conv2(x, edge_index)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.conv3(x, edge_index)
        x = torch.relu(x)
        x = self.conv4(x, edge_index)
        x = torch.relu(x)
        x = self.dropout(x)
        x = self.conv5(x, edge_index)
        x = torch.relu(x)
        x = self.conv6(x, edge_index)
        x = torch.relu(x)
        x = self.linear1(x)
        x = torch.relu(x)
        x = self.linear2(x)
        return x

# %%
# Define your loss function and optimizer
gnn_model = ComplexGNN(input_dim=features.shape[1], hidden_dim=16, output_dim=1)
# # loading a pytorch model from a saved state dict
# gnn_model.load_state_dict(torch.load('lat_long_node_GNN_rsrp.pth'))
loss_function = nn.MSELoss()  # For regression tasks
optimizer = optim.Adam(gnn_model.parameters(), lr=0.001)

# Create a DataLoader for batching your data
dataloader = DataLoader([data], batch_size=200)

# %%
# loading training and validation loss from a pickle file
import pickle
with open('lat_long_node_GNN_rsrp.pkl', 'rb') as f:
    training_acc, validation_acc = pickle.load(f)

# %%
# training_acc = []
# validation_acc = []

# %%
def get_validation(test_data):
    telecom_data = test_data
    # Extract relevant features and labels
    features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
    labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
    # # normalizing the labels using min-max normalization
    # labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))
    
     
    # Extract latitudes and longitudes
    latitudes = telecom_data['Latitude'].values
    longitudes = telecom_data['Longitude'].values
    
    # Calculate pairwise distances using Haversine formula
    coordinates = np.column_stack((latitudes, longitudes))
    dist_matrix = haversine_distances(np.radians(coordinates))
    
    # Define distance threshold for edges
    distance_threshold = 1  # For example, consider nodes within 10 km as neighbors
    
    # Create adjacency matrix based on distance threshold
    adj_matrix = (dist_matrix <= distance_threshold).astype(int)
    
    # Convert adjacency matrix to edge indices
    edge_indices = np.transpose(np.nonzero(adj_matrix))
    edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    
    loss_function = nn.MSELoss()
    
    X_train, y_train = features,labels
    y_train= y_train.reshape(-1,1)
    # Convert data to tensors
    x = torch.FloatTensor(X_train)
    y = torch.FloatTensor(y_train)
    # Create a graph data object using torch_geometric
    data = Data(x=x, edge_index=edge_indices, y=y)
    dataloader = DataLoader([data], batch_size=664)
    # Evaluation on test set
    gnn_model.eval()
    with torch.no_grad():
        for batch_data in dataloader:
            #print(batch_data.x.shape, batch_data.edge_index.shape, batch_data.y.shape)
            output = gnn_model(batch_data.x, batch_data.edge_index)
            loss = loss_function(output, batch_data.y)
            # print(f"Epoch [{epoch + 1}/{num_epochs}], Batch Loss: {(loss.item()):.4f}")
            return loss.item()

# %%
# Training loop
num_epochs = 2000

for epoch in range(num_epochs):
    #setting best validation loss to infinity
    best_val_loss = np.inf
    for batch_data in dataloader:
        optimizer.zero_grad()
        # print(batch_data.x.shape, batch_data.edge_index.shape, batch_data.y.shape)
        output = gnn_model(batch_data.x, batch_data.edge_index)
        loss = loss_function(output, batch_data.y)
        loss.backward()
        optimizer.step()
        print(f"Epoch [{epoch + 1}/{num_epochs}], Batch Loss: {(loss.item()):.4f}")
        val_loss = get_validation(test_data)
        print(f"Epoch [{epoch + 1}/{num_epochs}], Validation Loss: {(val_loss):.4f}")
        print("--------------------------------------------------")
        training_acc.append(loss.item())
        validation_acc.append(val_loss)
        # saving the model with best validation loss
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(gnn_model.state_dict(), 'lat_long_node_GNN_rsrp_best.pth')
# Out:
# Epoch [1/2000], Batch Loss: 165.0932
# Epoch [1/2000], Validation Loss: 201.7009
# --------------------------------------------------
# Epoch [2/2000], Batch Loss: 165.0756
# Epoch [2/2000], Validation Loss: 201.6787
# --------------------------------------------------
# Epoch [3/2000], Batch Loss: 165.0584
# Epoch [3/2000], Validation Loss: 201.6598
# --------------------------------------------------
# Epoch [4/2000], Batch Loss: 165.0413
# Epoch [4/2000], Validation Loss: 201.6340
# --------------------------------------------------
# Epoch [5/2000], Batch Loss: 165.0239
# Epoch [5/2000], Validation Loss: 201.6349
# --------------------------------------------------
# Epoch [6/2000], Batch Loss: 165.0054
# Epoch [6/2000], Validation Loss: 201.6829
# --------------------------------------------------
# Epoch [7/2000], Batch Loss: 164.9860
# Epoch [7/2000], Validation Loss: 201.7553
# --------------------------------------------------
# Epoch [8/2000], Batch Loss: 164.9671
# Epoch [8/2000], Validation Loss: 201.8430
# --------------------------------------------------
# Epoch [9/2000], Batch Loss: 164.9483
# Epoch [9/2000], Validation Loss: 201.9138
# --------------------------------------------------
# Epoch [10/2000], Batch Loss: 164.9292
# Epoch [10/2000], Validation Loss: 202.0162
# --------------------------------------------------
# Epoch [11/2000], Batch Loss: 164.9090
# Epoch [11/2000], Validation Loss: 202.1066
# --------------------------------------------------
# Epoch [12/2000], Batch Loss: 164.8885
# Epoch [12/2000], Validation Loss: 202.1987
# --------------------------------------------------
# Epoch [13/2000], Batch Loss: 164.8667
# Epoch [13/2000], Validation Loss: 202.2773
# --------------------------------------------------
# Epoch [14/2000], Batch Loss: 164.8440
# Epoch [14/2000], Validation Loss: 202.2828
# --------------------------------------------------
# Epoch [15/2000], Batch Loss: 164.8205
# Epoch [15/2000], Validation Loss: 202.2699
# --------------------------------------------------
# Epoch [16/2000], Batch Loss: 164.7966
# Epoch [16/2000], Validation Loss: 202.1901
# --------------------------------------------------
# Epoch [17/2000], Batch Loss: 164.7720
# Epoch [17/2000], Validation Loss: 202.0735
# --------------------------------------------------
# Epoch [18/2000], Batch Loss: 164.7473
# Epoch [18/2000], Validation Loss: 201.9425
# --------------------------------------------------
# Epoch [19/2000], Batch Loss: 164.7225
# Epoch [19/2000], Validation Loss: 201.8674
# --------------------------------------------------
# Epoch [20/2000], Batch Loss: 164.6981
# Epoch [20/2000], Validation Loss: 201.8309
# --------------------------------------------------
# Epoch [21/2000], Batch Loss: 164.6740
# Epoch [21/2000], Validation Loss: 201.8445
# --------------------------------------------------
# Epoch [22/2000], Batch Loss: 164.6500
# Epoch [22/2000], Validation Loss: 201.8517
# --------------------------------------------------
# Epoch [23/2000], Batch Loss: 164.6256
# Epoch [23/2000], Validation Loss: 201.8628
# --------------------------------------------------
# Epoch [24/2000], Batch Loss: 164.6014
# Epoch [24/2000], Validation Loss: 201.8338
# --------------------------------------------------
# Epoch [25/2000], Batch Loss: 164.5765
# Epoch [25/2000], Validation Loss: 201.7370
# --------------------------------------------------
# Epoch [26/2000], Batch Loss: 164.5511
# Epoch [26/2000], Validation Loss: 201.5571
# --------------------------------------------------
# Epoch [27/2000], Batch Loss: 164.5251
# Epoch [27/2000], Validation Loss: 201.3809
# --------------------------------------------------
# Epoch [28/2000], Batch Loss: 164.4986
# Epoch [28/2000], Validation Loss: 201.3285
# --------------------------------------------------
# Epoch [29/2000], Batch Loss: 164.4715
# Epoch [29/2000], Validation Loss: 201.4034
# --------------------------------------------------
# Epoch [30/2000], Batch Loss: 164.4442
# Epoch [30/2000], Validation Loss: 201.5410
# --------------------------------------------------
# Epoch [31/2000], Batch Loss: 164.4176
# Epoch [31/2000], Validation Loss: 201.7054
# --------------------------------------------------
# Epoch [32/2000], Batch Loss: 164.3913
# Epoch [32/2000], Validation Loss: 201.8046
# --------------------------------------------------
# Epoch [33/2000], Batch Loss: 164.3641
# Epoch [33/2000], Validation Loss: 201.8794
# --------------------------------------------------
# Epoch [34/2000], Batch Loss: 164.3362
# Epoch [34/2000], Validation Loss: 201.8813
# --------------------------------------------------
# Epoch [35/2000], Batch Loss: 164.3083
# Epoch [35/2000], Validation Loss: 201.8071
# --------------------------------------------------
# Epoch [36/2000], Batch Loss: 164.2805
# Epoch [36/2000], Validation Loss: 201.6984
# --------------------------------------------------
# Epoch [37/2000], Batch Loss: 164.2524
# Epoch [37/2000], Validation Loss: 201.6243
# --------------------------------------------------
# Epoch [38/2000], Batch Loss: 164.2243
# Epoch [38/2000], Validation Loss: 201.6405
# --------------------------------------------------
# Epoch [39/2000], Batch Loss: 164.1948
# Epoch [39/2000], Validation Loss: 201.7191
# --------------------------------------------------
# Epoch [40/2000], Batch Loss: 164.1646
# Epoch [40/2000], Validation Loss: 201.8237
# --------------------------------------------------
# Epoch [41/2000], Batch Loss: 164.1329
# Epoch [41/2000], Validation Loss: 201.9983
# --------------------------------------------------
# Epoch [42/2000], Batch Loss: 164.1012
# Epoch [42/2000], Validation Loss: 202.1178
# --------------------------------------------------
# Epoch [43/2000], Batch Loss: 164.0704
# Epoch [43/2000], Validation Loss: 202.0480
# --------------------------------------------------
# Epoch [44/2000], Batch Loss: 164.0392
# Epoch [44/2000], Validation Loss: 201.8404
# --------------------------------------------------
# Epoch [45/2000], Batch Loss: 164.0078
# Epoch [45/2000], Validation Loss: 201.5807
# --------------------------------------------------
# Epoch [46/2000], Batch Loss: 163.9767
# Epoch [46/2000], Validation Loss: 201.3286
# --------------------------------------------------
# Epoch [47/2000], Batch Loss: 163.9462
# Epoch [47/2000], Validation Loss: 201.1814
# --------------------------------------------------
# Epoch [48/2000], Batch Loss: 163.9151
# Epoch [48/2000], Validation Loss: 201.1451
# --------------------------------------------------
# Epoch [49/2000], Batch Loss: 163.8839
# Epoch [49/2000], Validation Loss: 201.1830
# --------------------------------------------------
# Epoch [50/2000], Batch Loss: 163.8530
# Epoch [50/2000], Validation Loss: 201.2128
# --------------------------------------------------
# Epoch [51/2000], Batch Loss: 163.8233
# Epoch [51/2000], Validation Loss: 201.1657
# --------------------------------------------------
# Epoch [52/2000], Batch Loss: 163.7942
# Epoch [52/2000], Validation Loss: 201.0618
# --------------------------------------------------
# Epoch [53/2000], Batch Loss: 163.7654
# Epoch [53/2000], Validation Loss: 200.8886
# --------------------------------------------------
# Epoch [54/2000], Batch Loss: 163.7372
# Epoch [54/2000], Validation Loss: 200.6830
# --------------------------------------------------
# Epoch [55/2000], Batch Loss: 163.7093
# Epoch [55/2000], Validation Loss: 200.4848
# --------------------------------------------------
# Epoch [56/2000], Batch Loss: 163.6824
# Epoch [56/2000], Validation Loss: 200.3553
# --------------------------------------------------
# Epoch [57/2000], Batch Loss: 163.6556
# Epoch [57/2000], Validation Loss: 200.3792
# --------------------------------------------------
# Epoch [58/2000], Batch Loss: 163.6286
# Epoch [58/2000], Validation Loss: 200.4587
# --------------------------------------------------
# Epoch [59/2000], Batch Loss: 163.6021
# Epoch [59/2000], Validation Loss: 200.5280
# --------------------------------------------------
# Epoch [60/2000], Batch Loss: 163.5756
# Epoch [60/2000], Validation Loss: 200.6150
# --------------------------------------------------
# Epoch [61/2000], Batch Loss: 163.5499
# Epoch [61/2000], Validation Loss: 200.6084
# --------------------------------------------------
# Epoch [62/2000], Batch Loss: 163.5250
# Epoch [62/2000], Validation Loss: 200.4824
# --------------------------------------------------
# Epoch [63/2000], Batch Loss: 163.4997
# Epoch [63/2000], Validation Loss: 200.3115
# --------------------------------------------------
# Epoch [64/2000], Batch Loss: 163.4746
# Epoch [64/2000], Validation Loss: 200.1062
# --------------------------------------------------
# Epoch [65/2000], Batch Loss: 163.4499
# Epoch [65/2000], Validation Loss: 199.9130
# --------------------------------------------------
# Epoch [66/2000], Batch Loss: 163.4260
# Epoch [66/2000], Validation Loss: 199.7614
# --------------------------------------------------
# Epoch [67/2000], Batch Loss: 163.4028
# Epoch [67/2000], Validation Loss: 199.6748
# --------------------------------------------------
# Epoch [94/2000], Batch Loss: 162.8741
# Epoch [94/2000], Validation Loss: 198.6735
# --------------------------------------------------
# Epoch [95/2000], Batch Loss: 162.8559
# Epoch [95/2000], Validation Loss: 198.5573
# --------------------------------------------------
# Epoch [96/2000], Batch Loss: 162.8377
# Epoch [96/2000], Validation Loss: 198.4006
# --------------------------------------------------
# Epoch [97/2000], Batch Loss: 162.8194
# Epoch [97/2000], Validation Loss: 198.2708
# --------------------------------------------------
# Epoch [98/2000], Batch Loss: 162.8012
# Epoch [98/2000], Validation Loss: 198.1840
# --------------------------------------------------
# Epoch [99/2000], Batch Loss: 162.7832
# Epoch [99/2000], Validation Loss: 198.1678
# --------------------------------------------------
# Epoch [100/2000], Batch Loss: 162.7642
# Epoch [100/2000], Validation Loss: 198.2582
# --------------------------------------------------
# Epoch [101/2000], Batch Loss: 162.7445
# Epoch [101/2000], Validation Loss: 198.3429
# --------------------------------------------------
# Epoch [102/2000], Batch Loss: 162.7254
# Epoch [102/2000], Validation Loss: 198.3803
# --------------------------------------------------
# Epoch [103/2000], Batch Loss: 162.7065
# Epoch [103/2000], Validation Loss: 198.3121
# --------------------------------------------------
# Epoch [104/2000], Batch Loss: 162.6874
# Epoch [104/2000], Validation Loss: 198.1952
# --------------------------------------------------
# Epoch [105/2000], Batch Loss: 162.6686
# Epoch [105/2000], Validation Loss: 198.1231
# --------------------------------------------------
# Epoch [106/2000], Batch Loss: 162.6501
# Epoch [106/2000], Validation Loss: 198.1072
# --------------------------------------------------
# Epoch [107/2000], Batch Loss: 162.6313
# Epoch [107/2000], Validation Loss: 198.1579
# --------------------------------------------------
# Epoch [108/2000], Batch Loss: 162.6118
# Epoch [108/2000], Validation Loss: 198.1872
# --------------------------------------------------
# Epoch [109/2000], Batch Loss: 162.5915
# Epoch [109/2000], Validation Loss: 198.2177
# --------------------------------------------------
# Epoch [110/2000], Batch Loss: 162.5708
# Epoch [110/2000], Validation Loss: 198.2126
# --------------------------------------------------
# Epoch [111/2000], Batch Loss: 162.5501
# Epoch [111/2000], Validation Loss: 198.1209
# --------------------------------------------------
# Epoch [112/2000], Batch Loss: 162.5293
# Epoch [112/2000], Validation Loss: 198.0125
# --------------------------------------------------
# Epoch [113/2000], Batch Loss: 162.5084
# Epoch [113/2000], Validation Loss: 197.9582
# --------------------------------------------------
# Epoch [114/2000], Batch Loss: 162.4879
# Epoch [114/2000], Validation Loss: 197.9361
# --------------------------------------------------
# Epoch [115/2000], Batch Loss: 162.4677
# Epoch [115/2000], Validation Loss: 197.9283
# --------------------------------------------------
# Epoch [116/2000], Batch Loss: 162.4479
# Epoch [116/2000], Validation Loss: 197.9150
# --------------------------------------------------
# Epoch [117/2000], Batch Loss: 162.4285
# Epoch [117/2000], Validation Loss: 197.8643
# --------------------------------------------------
# Epoch [118/2000], Batch Loss: 162.4097
# Epoch [118/2000], Validation Loss: 197.7591
# --------------------------------------------------
# Epoch [119/2000], Batch Loss: 162.3892
# Epoch [119/2000], Validation Loss: 197.7251
# --------------------------------------------------
# Epoch [120/2000], Batch Loss: 162.3686
# Epoch [120/2000], Validation Loss: 197.7532
# --------------------------------------------------
# Epoch [121/2000], Batch Loss: 162.3482
# Epoch [121/2000], Validation Loss: 197.7861
# --------------------------------------------------
# Epoch [122/2000], Batch Loss: 162.3277
# Epoch [122/2000], Validation Loss: 197.8025
# --------------------------------------------------
# Epoch [123/2000], Batch Loss: 162.3073
# Epoch [123/2000], Validation Loss: 197.8060
# --------------------------------------------------
# Epoch [124/2000], Batch Loss: 162.2868
# Epoch [124/2000], Validation Loss: 197.8333
# --------------------------------------------------
# Epoch [125/2000], Batch Loss: 162.2647
# Epoch [125/2000], Validation Loss: 197.8304
# --------------------------------------------------
# Epoch [126/2000], Batch Loss: 162.2432
# Epoch [126/2000], Validation Loss: 197.7882
# --------------------------------------------------
# Epoch [127/2000], Batch Loss: 162.2217
# Epoch [127/2000], Validation Loss: 197.7483
# --------------------------------------------------
# Epoch [128/2000], Batch Loss: 162.2002
# Epoch [128/2000], Validation Loss: 197.7158
# --------------------------------------------------
# Epoch [129/2000], Batch Loss: 162.1789
# Epoch [129/2000], Validation Loss: 197.6751
# --------------------------------------------------
# Epoch [130/2000], Batch Loss: 162.1580
# Epoch [130/2000], Validation Loss: 197.5901
# --------------------------------------------------
# Epoch [131/2000], Batch Loss: 162.1374
# Epoch [131/2000], Validation Loss: 197.4809
# --------------------------------------------------
# Epoch [132/2000], Batch Loss: 162.1170
# Epoch [132/2000], Validation Loss: 197.3730
# --------------------------------------------------
# Epoch [133/2000], Batch Loss: 162.0968
# Epoch [133/2000], Validation Loss: 197.3005
# --------------------------------------------------
# Epoch [134/2000], Batch Loss: 162.0767
# Epoch [134/2000], Validation Loss: 197.2606
# --------------------------------------------------
# Epoch [135/2000], Batch Loss: 162.0567
# Epoch [135/2000], Validation Loss: 197.2265
# --------------------------------------------------
# Epoch [136/2000], Batch Loss: 162.0372
# Epoch [136/2000], Validation Loss: 197.1902
# --------------------------------------------------
# Epoch [137/2000], Batch Loss: 162.0180
# Epoch [137/2000], Validation Loss: 197.1365
# --------------------------------------------------
# Epoch [138/2000], Batch Loss: 161.9991
# Epoch [138/2000], Validation Loss: 197.0866
# --------------------------------------------------
# Epoch [139/2000], Batch Loss: 161.9802
# Epoch [139/2000], Validation Loss: 197.0205
# --------------------------------------------------
# Epoch [140/2000], Batch Loss: 161.9615
# Epoch [140/2000], Validation Loss: 196.9852
# --------------------------------------------------
# Epoch [141/2000], Batch Loss: 161.9424
# Epoch [141/2000], Validation Loss: 197.0145
# --------------------------------------------------
# Epoch [142/2000], Batch Loss: 161.9220
# Epoch [142/2000], Validation Loss: 197.0566
# --------------------------------------------------
# Epoch [143/2000], Batch Loss: 161.9010
# Epoch [143/2000], Validation Loss: 197.0598
# --------------------------------------------------
# Epoch [144/2000], Batch Loss: 161.8802
# Epoch [144/2000], Validation Loss: 196.9525
# --------------------------------------------------
# Epoch [145/2000], Batch Loss: 161.8591
# Epoch [145/2000], Validation Loss: 196.7615
# --------------------------------------------------
# Epoch [146/2000], Batch Loss: 161.8378
# Epoch [146/2000], Validation Loss: 196.5473
# --------------------------------------------------
# Epoch [147/2000], Batch Loss: 161.8168
# Epoch [147/2000], Validation Loss: 196.4136
# --------------------------------------------------
# Epoch [148/2000], Batch Loss: 161.7966
# Epoch [148/2000], Validation Loss: 196.3686
# --------------------------------------------------
# Epoch [149/2000], Batch Loss: 161.7767
# Epoch [149/2000], Validation Loss: 196.4063
# --------------------------------------------------
# Epoch [150/2000], Batch Loss: 161.7553
# Epoch [150/2000], Validation Loss: 196.6316
# --------------------------------------------------
# Epoch [151/2000], Batch Loss: 161.7322
# Epoch [151/2000], Validation Loss: 196.9192
# --------------------------------------------------
# Epoch [152/2000], Batch Loss: 161.7090
# Epoch [152/2000], Validation Loss: 197.1004
# --------------------------------------------------
# Epoch [153/2000], Batch Loss: 161.6856
# Epoch [153/2000], Validation Loss: 197.1751
# --------------------------------------------------
# Epoch [154/2000], Batch Loss: 161.6613
# Epoch [154/2000], Validation Loss: 197.0689
# --------------------------------------------------
# Epoch [155/2000], Batch Loss: 161.6371
# Epoch [155/2000], Validation Loss: 196.8489
# --------------------------------------------------
# Epoch [156/2000], Batch Loss: 161.6132
# Epoch [156/2000], Validation Loss: 196.5912
# --------------------------------------------------
# Epoch [157/2000], Batch Loss: 161.5899
# Epoch [157/2000], Validation Loss: 196.4207
# --------------------------------------------------
# Epoch [158/2000], Batch Loss: 161.5663
# Epoch [158/2000], Validation Loss: 196.3736
# --------------------------------------------------
# Epoch [159/2000], Batch Loss: 161.5417
# Epoch [159/2000], Validation Loss: 196.4453
# --------------------------------------------------
# Epoch [160/2000], Batch Loss: 161.5190
# Epoch [160/2000], Validation Loss: 196.5165
# --------------------------------------------------
# Epoch [161/2000], Batch Loss: 161.4977
# Epoch [161/2000], Validation Loss: 196.5358
# --------------------------------------------------
# Epoch [162/2000], Batch Loss: 161.4778
# Epoch [162/2000], Validation Loss: 196.4277
# --------------------------------------------------
# Epoch [163/2000], Batch Loss: 161.4578
# Epoch [163/2000], Validation Loss: 196.2423
# --------------------------------------------------
# Epoch [164/2000], Batch Loss: 161.4380
# Epoch [164/2000], Validation Loss: 196.0442
# --------------------------------------------------
# Epoch [165/2000], Batch Loss: 161.4188
# Epoch [165/2000], Validation Loss: 195.9012
# --------------------------------------------------
# Epoch [166/2000], Batch Loss: 161.4004
# Epoch [166/2000], Validation Loss: 195.8319
# --------------------------------------------------
# Epoch [167/2000], Batch Loss: 161.3824
# Epoch [167/2000], Validation Loss: 195.8305
# --------------------------------------------------
# Epoch [168/2000], Batch Loss: 161.3644
# Epoch [168/2000], Validation Loss: 195.8840
# --------------------------------------------------
# Epoch [169/2000], Batch Loss: 161.3462
# Epoch [169/2000], Validation Loss: 195.9089
# --------------------------------------------------
# Epoch [170/2000], Batch Loss: 161.3275
# Epoch [170/2000], Validation Loss: 195.9647
# --------------------------------------------------
# Epoch [171/2000], Batch Loss: 161.3084
# Epoch [171/2000], Validation Loss: 195.9628
# --------------------------------------------------
# Epoch [172/2000], Batch Loss: 161.2892
# Epoch [172/2000], Validation Loss: 195.9103
# --------------------------------------------------
# Epoch [173/2000], Batch Loss: 161.2698
# Epoch [173/2000], Validation Loss: 195.7783
# --------------------------------------------------
# Epoch [174/2000], Batch Loss: 161.2499
# Epoch [174/2000], Validation Loss: 195.7052
# --------------------------------------------------
# Epoch [175/2000], Batch Loss: 161.2291
# Epoch [175/2000], Validation Loss: 195.6833
# --------------------------------------------------
# Epoch [176/2000], Batch Loss: 161.2084
# Epoch [176/2000], Validation Loss: 195.7093
# --------------------------------------------------
# Epoch [177/2000], Batch Loss: 161.1875
# Epoch [177/2000], Validation Loss: 195.7171
# --------------------------------------------------
# Epoch [178/2000], Batch Loss: 161.1669
# Epoch [178/2000], Validation Loss: 195.7031
# --------------------------------------------------
# Epoch [179/2000], Batch Loss: 161.1465
# Epoch [179/2000], Validation Loss: 195.6487
# --------------------------------------------------
# Epoch [180/2000], Batch Loss: 161.1255
# Epoch [180/2000], Validation Loss: 195.5180
# --------------------------------------------------
# Epoch [181/2000], Batch Loss: 161.1044
# Epoch [181/2000], Validation Loss: 195.4133
# --------------------------------------------------
# Epoch [182/2000], Batch Loss: 161.0824
# Epoch [182/2000], Validation Loss: 195.3375
# --------------------------------------------------
# Epoch [183/2000], Batch Loss: 161.0604
# Epoch [183/2000], Validation Loss: 195.2864
# --------------------------------------------------
# Epoch [184/2000], Batch Loss: 161.0383
# Epoch [184/2000], Validation Loss: 195.2404
# --------------------------------------------------
# Epoch [185/2000], Batch Loss: 161.0167
# Epoch [185/2000], Validation Loss: 195.1220
# --------------------------------------------------
# Epoch [186/2000], Batch Loss: 160.9959
# Epoch [186/2000], Validation Loss: 194.9627
# --------------------------------------------------
# Epoch [187/2000], Batch Loss: 160.9754
# Epoch [187/2000], Validation Loss: 194.7722
# --------------------------------------------------
# Epoch [188/2000], Batch Loss: 160.9552
# Epoch [188/2000], Validation Loss: 194.6039
# --------------------------------------------------
# Epoch [189/2000], Batch Loss: 160.9350
# Epoch [189/2000], Validation Loss: 194.5173
# --------------------------------------------------
# Epoch [190/2000], Batch Loss: 160.9150
# Epoch [190/2000], Validation Loss: 194.4937
# --------------------------------------------------
# Epoch [191/2000], Batch Loss: 160.8954
# Epoch [191/2000], Validation Loss: 194.4196
# --------------------------------------------------
# Epoch [192/2000], Batch Loss: 160.8760
# Epoch [192/2000], Validation Loss: 194.3774
# --------------------------------------------------
# Epoch [193/2000], Batch Loss: 160.8561
# Epoch [193/2000], Validation Loss: 194.3093
# --------------------------------------------------
# Epoch [194/2000], Batch Loss: 160.8363
# Epoch [194/2000], Validation Loss: 194.2056
# --------------------------------------------------
# Epoch [195/2000], Batch Loss: 160.8168
# Epoch [195/2000], Validation Loss: 194.0959
# --------------------------------------------------
# Epoch [196/2000], Batch Loss: 160.7966
# Epoch [196/2000], Validation Loss: 194.0870
# --------------------------------------------------
# Epoch [197/2000], Batch Loss: 160.7750
# Epoch [197/2000], Validation Loss: 194.1417
# --------------------------------------------------
# Epoch [198/2000], Batch Loss: 160.7531
# Epoch [198/2000], Validation Loss: 194.1874
# --------------------------------------------------
# Epoch [199/2000], Batch Loss: 160.7315
# Epoch [199/2000], Validation Loss: 194.1943
# --------------------------------------------------
# Epoch [200/2000], Batch Loss: 160.7099
# Epoch [200/2000], Validation Loss: 194.1256
# --------------------------------------------------
# Epoch [201/2000], Batch Loss: 160.6884
# Epoch [201/2000], Validation Loss: 193.9800
# --------------------------------------------------
# Epoch [202/2000], Batch Loss: 160.6664
# Epoch [202/2000], Validation Loss: 193.8542
# --------------------------------------------------
# Epoch [203/2000], Batch Loss: 160.6448
# Epoch [203/2000], Validation Loss: 193.7489
# --------------------------------------------------
# Epoch [204/2000], Batch Loss: 160.6232
# Epoch [204/2000], Validation Loss: 193.7012
# --------------------------------------------------
# Epoch [205/2000], Batch Loss: 160.6017
# Epoch [205/2000], Validation Loss: 193.6618
# --------------------------------------------------
# Epoch [206/2000], Batch Loss: 160.5794
# Epoch [206/2000], Validation Loss: 193.6314
# --------------------------------------------------
# Epoch [207/2000], Batch Loss: 160.5577
# Epoch [207/2000], Validation Loss: 193.7171
# --------------------------------------------------
# Epoch [208/2000], Batch Loss: 160.5338
# Epoch [208/2000], Validation Loss: 193.8665
# --------------------------------------------------
# Epoch [209/2000], Batch Loss: 160.5088
# Epoch [209/2000], Validation Loss: 193.9620
# --------------------------------------------------
# Epoch [210/2000], Batch Loss: 160.4834
# Epoch [210/2000], Validation Loss: 193.8965
# --------------------------------------------------
# Epoch [211/2000], Batch Loss: 160.4573
# Epoch [211/2000], Validation Loss: 193.7300
# --------------------------------------------------
# Epoch [212/2000], Batch Loss: 160.4294
# Epoch [212/2000], Validation Loss: 193.5655
# --------------------------------------------------
# Epoch [213/2000], Batch Loss: 160.4010
# Epoch [213/2000], Validation Loss: 193.5263
# --------------------------------------------------
# Epoch [214/2000], Batch Loss: 160.3722
# Epoch [214/2000], Validation Loss: 193.5108
# --------------------------------------------------
# Epoch [215/2000], Batch Loss: 160.3433
# Epoch [215/2000], Validation Loss: 193.6334
# --------------------------------------------------
# Epoch [216/2000], Batch Loss: 160.3146
# Epoch [216/2000], Validation Loss: 193.6507
# --------------------------------------------------
# Epoch [217/2000], Batch Loss: 160.2871
# Epoch [217/2000], Validation Loss: 193.4989
# --------------------------------------------------
# Epoch [218/2000], Batch Loss: 160.2593
# Epoch [218/2000], Validation Loss: 193.3469
# --------------------------------------------------
# Epoch [219/2000], Batch Loss: 160.2312
# Epoch [219/2000], Validation Loss: 193.2158
# --------------------------------------------------
# Epoch [220/2000], Batch Loss: 160.2031
# Epoch [220/2000], Validation Loss: 193.0879
# --------------------------------------------------
# Epoch [221/2000], Batch Loss: 160.1757
# Epoch [221/2000], Validation Loss: 192.9636
# --------------------------------------------------
# Epoch [222/2000], Batch Loss: 160.1487
# Epoch [222/2000], Validation Loss: 192.8318
# --------------------------------------------------
# Epoch [223/2000], Batch Loss: 160.1215
# Epoch [249/2000], Validation Loss: 190.7408
# --------------------------------------------------
# Epoch [250/2000], Batch Loss: 159.3631
# Epoch [250/2000], Validation Loss: 190.6783
# --------------------------------------------------
# Epoch [251/2000], Batch Loss: 159.3395
# Epoch [251/2000], Validation Loss: 190.5487
# --------------------------------------------------
# Epoch [252/2000], Batch Loss: 159.3159
# Epoch [252/2000], Validation Loss: 190.4804
# --------------------------------------------------
# Epoch [253/2000], Batch Loss: 159.2932
# Epoch [253/2000], Validation Loss: 190.4138
# --------------------------------------------------
# Epoch [254/2000], Batch Loss: 159.2715
# Epoch [254/2000], Validation Loss: 190.2523
# --------------------------------------------------
# Epoch [255/2000], Batch Loss: 159.2499
# Epoch [255/2000], Validation Loss: 190.0849
# --------------------------------------------------
# Epoch [256/2000], Batch Loss: 159.2280
# Epoch [256/2000], Validation Loss: 190.0389
# --------------------------------------------------
# Epoch [257/2000], Batch Loss: 159.2054
# Epoch [257/2000], Validation Loss: 190.0602
# --------------------------------------------------
# Epoch [258/2000], Batch Loss: 159.1827
# Epoch [258/2000], Validation Loss: 190.0177
# --------------------------------------------------
# Epoch [259/2000], Batch Loss: 159.1604
# Epoch [259/2000], Validation Loss: 189.9076
# --------------------------------------------------
# Epoch [260/2000], Batch Loss: 159.1382
# Epoch [260/2000], Validation Loss: 189.7948
# --------------------------------------------------
# Epoch [261/2000], Batch Loss: 159.1157
# Epoch [261/2000], Validation Loss: 189.7802
# --------------------------------------------------
# Epoch [262/2000], Batch Loss: 159.0933
# Epoch [262/2000], Validation Loss: 189.8277
# --------------------------------------------------
# Epoch [263/2000], Batch Loss: 159.0706
# Epoch [263/2000], Validation Loss: 189.9421
# --------------------------------------------------
# Epoch [264/2000], Batch Loss: 159.0453
# Epoch [264/2000], Validation Loss: 190.0492
# --------------------------------------------------
# Epoch [265/2000], Batch Loss: 159.0202
# Epoch [265/2000], Validation Loss: 190.0841
# --------------------------------------------------
# Epoch [266/2000], Batch Loss: 158.9952
# Epoch [266/2000], Validation Loss: 189.9751
# --------------------------------------------------
# Epoch [267/2000], Batch Loss: 158.9706
# Epoch [267/2000], Validation Loss: 189.7382
# --------------------------------------------------
# Epoch [268/2000], Batch Loss: 158.9453
# Epoch [268/2000], Validation Loss: 189.5143
# --------------------------------------------------
# Epoch [269/2000], Batch Loss: 158.9205
# Epoch [269/2000], Validation Loss: 189.4524
# --------------------------------------------------
# Epoch [270/2000], Batch Loss: 158.8959
# Epoch [270/2000], Validation Loss: 189.5118
# --------------------------------------------------
# Epoch [271/2000], Batch Loss: 158.8712
# Epoch [271/2000], Validation Loss: 189.6008
# --------------------------------------------------
# Epoch [272/2000], Batch Loss: 158.8456
# Epoch [272/2000], Validation Loss: 189.7601
# --------------------------------------------------
# Epoch [273/2000], Batch Loss: 158.8193
# Epoch [273/2000], Validation Loss: 189.8052
# --------------------------------------------------
# Epoch [274/2000], Batch Loss: 158.7939
# Epoch [274/2000], Validation Loss: 189.7130
# --------------------------------------------------
# Epoch [353/2000], Batch Loss: 156.6542
# Epoch [353/2000], Validation Loss: 183.8404
# --------------------------------------------------
# Epoch [354/2000], Batch Loss: 156.6155
# Epoch [354/2000], Validation Loss: 183.7497
# --------------------------------------------------
# Epoch [355/2000], Batch Loss: 156.5762
# Epoch [355/2000], Validation Loss: 183.6444
# --------------------------------------------------
# Epoch [356/2000], Batch Loss: 156.5332
# Epoch [356/2000], Validation Loss: 183.5440
# --------------------------------------------------
# Epoch [357/2000], Batch Loss: 156.4893
# Epoch [357/2000], Validation Loss: 183.3830
# --------------------------------------------------
# Epoch [358/2000], Batch Loss: 156.4452
# Epoch [358/2000], Validation Loss: 183.2087
# --------------------------------------------------
# Epoch [359/2000], Batch Loss: 156.3994
# Epoch [359/2000], Validation Loss: 183.1217
# --------------------------------------------------
# Epoch [360/2000], Batch Loss: 156.3515
# Epoch [360/2000], Validation Loss: 183.0637
# ...
# Epoch [1882/2000], Batch Loss: 91.9038
# Epoch [1882/2000], Validation Loss: 101.2004
# --------------------------------------------------
# Epoch [1883/2000], Batch Loss: 91.8256
# Epoch [1883/2000], Validation Loss: 101.1705
# --------------------------------------------------
# Epoch [1884/2000], Batch Loss: 91.7448
# Epoch [1884/2000], Validation Loss: 101.1523
# --------------------------------------------------
# Epoch [1885/2000], Batch Loss: 91.6651
# Epoch [1885/2000], Validation Loss: 101.0198
# --------------------------------------------------
# Epoch [1886/2000], Batch Loss: 91.5849
# Epoch [1886/2000], Validation Loss: 101.0506
# --------------------------------------------------
# Epoch [1887/2000], Batch Loss: 91.5058
# Epoch [1887/2000], Validation Loss: 100.9500
# --------------------------------------------------
# Epoch [1888/2000], Batch Loss: 91.4275
# Epoch [1888/2000], Validation Loss: 100.7876
# --------------------------------------------------
# Epoch [1889/2000], Batch Loss: 91.3513
# Epoch [1889/2000], Validation Loss: 100.7110
# --------------------------------------------------
# Epoch [1890/2000], Batch Loss: 91.2800
# Epoch [1890/2000], Validation Loss: 100.5087
# --------------------------------------------------
# Epoch [1891/2000], Batch Loss: 91.2120
# Epoch [1891/2000], Validation Loss: 100.5191
# --------------------------------------------------
# Epoch [1892/2000], Batch Loss: 91.1403
# Epoch [1892/2000], Validation Loss: 100.3921
# --------------------------------------------------
# Epoch [1893/2000], Batch Loss: 91.0730
# Epoch [1893/2000], Validation Loss: 100.2572
# --------------------------------------------------
# Epoch [1894/2000], Batch Loss: 91.0084
# Epoch [1894/2000], Validation Loss: 100.2300
# --------------------------------------------------
# Epoch [1895/2000], Batch Loss: 90.9465
# Epoch [1895/2000], Validation Loss: 100.0163
# --------------------------------------------------
# Epoch [1896/2000], Batch Loss: 90.8818
# Epoch [1896/2000], Validation Loss: 99.8805
# --------------------------------------------------
# Epoch [1897/2000], Batch Loss: 90.8178
# Epoch [1897/2000], Validation Loss: 99.9130
# --------------------------------------------------
# Epoch [1898/2000], Batch Loss: 90.7548
# Epoch [1898/2000], Validation Loss: 99.7940
# --------------------------------------------------
# Epoch [1899/2000], Batch Loss: 90.6905
# Epoch [1924/2000], Validation Loss: 98.1508
# --------------------------------------------------
# Epoch [1925/2000], Batch Loss: 88.8799
# Epoch [1925/2000], Validation Loss: 97.9433
# --------------------------------------------------
# Epoch [1926/2000], Batch Loss: 88.7968
# Epoch [1926/2000], Validation Loss: 97.8355
# --------------------------------------------------
# Epoch [1927/2000], Batch Loss: 88.7125
# Epoch [1927/2000], Validation Loss: 97.9894
# --------------------------------------------------
# Epoch [1928/2000], Batch Loss: 88.6291
# Epoch [1928/2000], Validation Loss: 97.4506
# --------------------------------------------------
# Epoch [1929/2000], Batch Loss: 88.5424
# Epoch [1929/2000], Validation Loss: 97.4550
# --------------------------------------------------
# Epoch [1930/2000], Batch Loss: 88.4509
# Epoch [1930/2000], Validation Loss: 97.2672
# --------------------------------------------------
# Epoch [1931/2000], Batch Loss: 88.3543
# Epoch [1931/2000], Validation Loss: 97.1059
# --------------------------------------------------
# Epoch [1932/2000], Batch Loss: 88.2508
# Epoch [1932/2000], Validation Loss: 97.3788
# --------------------------------------------------
# Epoch [1933/2000], Batch Loss: 88.1388
# Epoch [1933/2000], Validation Loss: 97.0093
# --------------------------------------------------
# Epoch [1934/2000], Batch Loss: 88.0215
# Epoch [1934/2000], Validation Loss: 97.1251
# --------------------------------------------------
# Epoch [1935/2000], Batch Loss: 87.8980
# Epoch [1935/2000], Validation Loss: 96.8783
# --------------------------------------------------
# Epoch [1936/2000], Batch Loss: 87.7624
# Epoch [1936/2000], Validation Loss: 96.8375
# --------------------------------------------------
# Epoch [1937/2000], Batch Loss: 87.6183
# Epoch [1937/2000], Validation Loss: 96.9187
# --------------------------------------------------
# Epoch [1938/2000], Batch Loss: 87.4670
# Epoch [1938/2000], Validation Loss: 96.4954
# --------------------------------------------------
# Epoch [1939/2000], Batch Loss: 87.2956
# Epoch [1939/2000], Validation Loss: 96.5424
# --------------------------------------------------
# Epoch [1940/2000], Batch Loss: 87.0927
# Epoch [1940/2000], Validation Loss: 96.2410
# --------------------------------------------------
# Epoch [1941/2000], Batch Loss: 86.8831
# Epoch [1941/2000], Validation Loss: 96.0245
# --------------------------------------------------
# Epoch [1942/2000], Batch Loss: 86.6722
# Epoch [1942/2000], Validation Loss: 95.7703
# --------------------------------------------------
# Epoch [1943/2000], Batch Loss: 86.4661
# Epoch [1943/2000], Validation Loss: 94.9788
# --------------------------------------------------
# Epoch [1944/2000], Batch Loss: 86.2593
# Epoch [1944/2000], Validation Loss: 94.6694
# --------------------------------------------------
# Epoch [1945/2000], Batch Loss: 86.0354
# Epoch [1945/2000], Validation Loss: 94.0198
# --------------------------------------------------
# Epoch [1946/2000], Batch Loss: 85.8146
# Epoch [1946/2000], Validation Loss: 93.7533
# --------------------------------------------------
# Epoch [1947/2000], Batch Loss: 85.6022
# Epoch [1947/2000], Validation Loss: 93.2545
# --------------------------------------------------
# Epoch [1948/2000], Batch Loss: 85.4024
# Epoch [1948/2000], Validation Loss: 92.8655
# --------------------------------------------------
# Epoch [1949/2000], Batch Loss: 85.2149
# Epoch [1949/2000], Validation Loss: 92.3785
# --------------------------------------------------
# Epoch [1950/2000], Batch Loss: 85.0262
# Epoch [1950/2000], Validation Loss: 92.2022
# --------------------------------------------------
# Epoch [1951/2000], Batch Loss: 84.8299
# Epoch [1951/2000], Validation Loss: 92.0103
# --------------------------------------------------
# Epoch [1952/2000], Batch Loss: 84.6272
# Epoch [1952/2000], Validation Loss: 91.8378
# --------------------------------------------------
# Epoch [1953/2000], Batch Loss: 84.4267
# Epoch [1953/2000], Validation Loss: 91.6888
# --------------------------------------------------
# Epoch [1954/2000], Batch Loss: 84.2270
# Epoch [1954/2000], Validation Loss: 91.2278
# --------------------------------------------------
# Epoch [1955/2000], Batch Loss: 84.0317
# Epoch [1955/2000], Validation Loss: 91.1621
# --------------------------------------------------
# Epoch [1956/2000], Batch Loss: 83.8391
# Epoch [1956/2000], Validation Loss: 90.7859
# --------------------------------------------------
# Epoch [1957/2000], Batch Loss: 83.6448
# Epoch [1957/2000], Validation Loss: 90.7258
# --------------------------------------------------
# Epoch [1958/2000], Batch Loss: 83.4422
# Epoch [1958/2000], Validation Loss: 90.7429
# --------------------------------------------------
# Epoch [1959/2000], Batch Loss: 83.2387
# Epoch [1959/2000], Validation Loss: 90.3613
# --------------------------------------------------
# Epoch [1960/2000], Batch Loss: 83.0319
# Epoch [1960/2000], Validation Loss: 90.4668
# --------------------------------------------------
# Epoch [1961/2000], Batch Loss: 82.8221
# Epoch [1961/2000], Validation Loss: 89.9889
# --------------------------------------------------
# Epoch [1962/2000], Batch Loss: 82.6162
# Epoch [1962/2000], Validation Loss: 90.1022
# --------------------------------------------------
# Epoch [1963/2000], Batch Loss: 82.4104
# Epoch [1963/2000], Validation Loss: 89.8028
# --------------------------------------------------
# Epoch [1964/2000], Batch Loss: 82.2040
# Epoch [1964/2000], Validation Loss: 89.7566
# --------------------------------------------------
# Epoch [1965/2000], Batch Loss: 81.9979
# Epoch [1965/2000], Validation Loss: 89.6026
# --------------------------------------------------
# Epoch [1966/2000], Batch Loss: 81.7965
# Epoch [1966/2000], Validation Loss: 89.3762
# --------------------------------------------------
# Epoch [1967/2000], Batch Loss: 81.5967
# Epoch [1967/2000], Validation Loss: 89.3348
# --------------------------------------------------
# Epoch [1968/2000], Batch Loss: 81.3996
# Epoch [1968/2000], Validation Loss: 89.0691
# --------------------------------------------------
# Epoch [1969/2000], Batch Loss: 81.2044
# Epoch [1969/2000], Validation Loss: 88.9139
# --------------------------------------------------
# Epoch [1970/2000], Batch Loss: 81.0146
# Epoch [1970/2000], Validation Loss: 88.7807
# --------------------------------------------------
# Epoch [1971/2000], Batch Loss: 80.8236
# Epoch [1971/2000], Validation Loss: 88.3848
# --------------------------------------------------
# Epoch [1972/2000], Batch Loss: 80.6352
# Epoch [1972/2000], Validation Loss: 88.4550
# --------------------------------------------------
# Epoch [1973/2000], Batch Loss: 80.4441
# Epoch [1973/2000], Validation Loss: 87.9172
# --------------------------------------------------
# Epoch [1974/2000], Batch Loss: 80.2564
# Epoch [1974/2000], Validation Loss: 88.0957
# --------------------------------------------------
# Epoch [1975/2000], Batch Loss: 80.0741
# Epoch [1975/2000], Validation Loss: 87.4252
# --------------------------------------------------
# Epoch [1976/2000], Batch Loss: 79.9009
# Epoch [1976/2000], Validation Loss: 87.9145
# --------------------------------------------------
# Epoch [1977/2000], Batch Loss: 79.7342
# Epoch [1977/2000], Validation Loss: 86.8870
# --------------------------------------------------
# Epoch [1978/2000], Batch Loss: 79.5744
# Epoch [1978/2000], Validation Loss: 87.9106
# --------------------------------------------------
# Epoch [1979/2000], Batch Loss: 79.4076
# Epoch [1979/2000], Validation Loss: 86.3745
# --------------------------------------------------
# Epoch [1980/2000], Batch Loss: 79.2424
# Epoch [1980/2000], Validation Loss: 87.9802
# --------------------------------------------------
# Epoch [1981/2000], Batch Loss: 79.0850
# Epoch [1981/2000], Validation Loss: 85.5619
# --------------------------------------------------
# Epoch [1982/2000], Batch Loss: 78.9380
# Epoch [1982/2000], Validation Loss: 88.2332
# --------------------------------------------------
# Epoch [1983/2000], Batch Loss: 78.8124
# Epoch [1983/2000], Validation Loss: 84.2338
# --------------------------------------------------
# Epoch [1984/2000], Batch Loss: 78.7146
# Epoch [1984/2000], Validation Loss: 89.5211
# --------------------------------------------------
# Epoch [1985/2000], Batch Loss: 78.6745
# Epoch [1985/2000], Validation Loss: 81.8246
# --------------------------------------------------
# Epoch [1986/2000], Batch Loss: 78.7725
# Epoch [1986/2000], Validation Loss: 93.1713
# --------------------------------------------------
# Epoch [1987/2000], Batch Loss: 79.1489
# Epoch [1987/2000], Validation Loss: 78.0584
# --------------------------------------------------
# Epoch [1988/2000], Batch Loss: 80.0663
# Epoch [1988/2000], Validation Loss: 101.4138
# --------------------------------------------------
# Epoch [1989/2000], Batch Loss: 81.5602
# Epoch [1989/2000], Validation Loss: 75.4684
# --------------------------------------------------
# Epoch [1990/2000], Batch Loss: 83.1918
# Epoch [1990/2000], Validation Loss: 104.2914
# --------------------------------------------------
# Epoch [1991/2000], Batch Loss: 82.6455
# Epoch [1991/2000], Validation Loss: 76.7160
# --------------------------------------------------
# Epoch [1992/2000], Batch Loss: 79.8042
# Epoch [1992/2000], Validation Loss: 85.4378
# --------------------------------------------------
# Epoch [1993/2000], Batch Loss: 77.4524
# Epoch [1993/2000], Validation Loss: 91.1957
# --------------------------------------------------
# Epoch [1994/2000], Batch Loss: 78.2811
# Epoch [1994/2000], Validation Loss: 75.6562
# --------------------------------------------------
# Epoch [1995/2000], Batch Loss: 80.0508
# Epoch [1995/2000], Validation Loss: 95.3131
# --------------------------------------------------
# Epoch [1996/2000], Batch Loss: 79.3033
# Epoch [1996/2000], Validation Loss: 79.5027
# --------------------------------------------------
# Epoch [1997/2000], Batch Loss: 77.2860
# Epoch [1997/2000], Validation Loss: 79.4609
# --------------------------------------------------
# Epoch [1998/2000], Batch Loss: 77.1541
# Epoch [1998/2000], Validation Loss: 92.7231
# --------------------------------------------------
# Epoch [1999/2000], Batch Loss: 78.3899
# Epoch [1999/2000], Validation Loss: 76.2741
# --------------------------------------------------
# Epoch [2000/2000], Batch Loss: 78.1996
# Epoch [2000/2000], Validation Loss: 85.9419
# --------------------------------------------------

# %%
# plot training and validation loss
import matplotlib.pyplot as plt
plt.plot(training_acc, label='Training loss')
plt.plot(validation_acc, label='Validation loss')
plt.legend()
plt.show()

# %%
print(min(validation_acc))
#122.72
# Out:
# 65.55347442626953

# %%
len(validation_acc)
# Out:
# 11005

# %%
# print last 10 validation losses
validation_acc[-10:]
# Out:
# [76.71598052978516,
#  85.4377670288086,
#  91.19566345214844,
#  75.65624237060547,
#  95.31307983398438,
#  79.50267791748047,
#  79.46087646484375,
#  92.72312927246094,
#  76.27410125732422,
#  85.94194793701172]

# %%
# print last 100 validation losses
print(validation_acc[-100:])
# Out:
# [99.48250579833984, 99.30841827392578, 99.45175170898438, 99.2787094116211, 99.20259857177734, 99.26128387451172, 98.99451446533203, 99.0519027709961, 99.0507583618164, 98.85538482666016, 98.86589050292969, 98.78237915039062, 98.70154571533203, 98.80227661132812, 98.5480728149414, 98.51824188232422, 98.5300521850586, 98.33113861083984, 98.46385192871094, 98.23704528808594, 98.13346099853516, 98.3337631225586, 97.91302490234375, 98.15076446533203, 97.94328308105469, 97.83546447753906, 97.98936462402344, 97.45056915283203, 97.45499420166016, 97.2672119140625, 97.10594177246094, 97.3787612915039, 97.0092544555664, 97.12505340576172, 96.87834930419922, 96.83753204345703, 96.91868591308594, 96.495361328125, 96.54236602783203, 96.24102020263672, 96.02452087402344, 95.77027893066406, 94.97882843017578, 94.66944122314453, 94.01976776123047, 93.7532730102539, 93.25453186035156, 92.86546325683594, 92.37850952148438, 92.20219421386719, 92.01032257080078, 91.83782196044922, 91.68879699707031, 91.2277603149414, 91.16207122802734, 90.785888671875, 90.7258071899414, 90.74290466308594, 90.36134338378906, 90.46683502197266, 89.9888916015625, 90.10221099853516, 89.80284881591797, 89.75658416748047, 89.60255432128906, 89.37615203857422, 89.33479309082031, 89.06909942626953, 88.91392517089844, 88.7807388305664, 88.38481903076172, 88.45504760742188, 87.91720581054688, 88.09573364257812, 87.42515563964844, 87.91446685791016, 86.88697814941406, 87.91062927246094, 86.37447357177734, 87.98015594482422, 85.56188201904297, 88.2331771850586, 84.23379516601562, 89.52111053466797, 81.82455444335938, 93.17134857177734, 78.0583724975586, 101.4138412475586, 75.4683609008789, 104.2914047241211, 76.71598052978516, 85.4377670288086, 91.19566345214844, 75.65624237060547, 95.31307983398438, 79.50267791748047, 79.46087646484375, 92.72312927246094, 76.27410125732422, 85.94194793701172]

# %%
# saving the model
torch.save(gnn_model.state_dict(), 'lat_long_node_GNN_rsrp.pth')

# %%
# saving the validation loss and training loss as a pickle file
import pickle
with open('lat_long_node_GNN_rsrp.pkl', 'wb') as f:
    pickle.dump([training_acc, validation_acc], f)

# %%
def evaluate_model(telecom_data):
    # Extract relevant features and labels
    features = telecom_data[['PCell_Downlink_Num_RBs', 'PCell_Downlink_TB_Size', 'SCell_Downlink_TB_Size','SCell_Downlink_Num_RBs','SCell_Downlink_RBs_MCS_28','SCell_Downlink_RBs_MCS_31','PCell_RSRP_max','SCell_RSRP_max']].values
    labels = telecom_data['datarate'].values  # Replace 'label' with your actual label column
    
    # # Normalizing the labels using min-max normalization
    # labels = ((np.max(labels)-labels)*100)/(np.max(labels)-np.min(labels))
    
    # Extract latitudes and longitudes
    latitudes = telecom_data['Latitude'].values
    longitudes = telecom_data['Longitude'].values
    
    # Calculate pairwise distances using Haversine formula
    coordinates = np.column_stack((latitudes, longitudes))
    dist_matrix = haversine_distances(np.radians(coordinates))
    
    # Define distance threshold for edges
    distance_threshold = 1  # Consider nodes within specified distance as neighbors
    
    # Create adjacency matrix based on distance threshold
    adj_matrix = (dist_matrix <= distance_threshold).astype(int)
    
    # Convert adjacency matrix to edge indices
    edge_indices = np.transpose(np.nonzero(adj_matrix))
    edge_indices = torch.tensor(edge_indices, dtype=torch.long).t().contiguous()
    
    loss_function = nn.MSELoss()
    
    X_train, y_train = features,labels
    y_train= y_train.reshape(-1,1)
    
    # Convert data to tensors
    x = torch.FloatTensor(X_train)
    y = torch.FloatTensor(y_train)
    
    # Create a graph data object using torch_geometric
    data = Data(x=x, edge_index=edge_indices, y=y)
    dataloader = DataLoader([data], batch_size=20)
    
    # Evaluation on test set
    gnn_model.eval()
    
    true_labels = []
    predicted_labels = []
    
    with torch.no_grad():
        for batch_data in dataloader:
            output = gnn_model(batch_data.x, batch_data.edge_index)
            
            true_labels.extend(batch_data.y.numpy())
            predicted_labels.extend(output.numpy())

    return true_labels, predicted_labels

# %%
a,b = evaluate_model(telecom_data=test_data)

# %%
print(a)
# Out:
# [array([68.69766], dtype=float32), array([64.0784], dtype=float32), array([48.409866], dtype=float32), array([68.25421], dtype=float32), array([85.84436], dtype=float32), array([52.105274], dtype=float32), array([52.844357], dtype=float32), array([49.14895], dtype=float32), array([73.464745], dtype=float32), array([48.409866], dtype=float32), array([66.7391], dtype=float32), array([81.705505], dtype=float32), array([35.10639], dtype=float32), array([41.75813], dtype=float32), array([49.888027], dtype=float32), array([73.68647], dtype=float32), array([30.302359], dtype=float32), array([65.076164], dtype=float32), array([61.3438], dtype=float32), array([92.0157], dtype=float32), array([28.824194], dtype=float32), array([30.6719], dtype=float32), array([60.604717], dtype=float32), array([57.278847], dtype=float32), array([77.75142], dtype=float32), array([42.866753], dtype=float32), array([74.092964], dtype=float32), array([90.35276], dtype=float32), array([60.235176], dtype=float32), array([50.99665], dtype=float32), array([68.06944], dtype=float32), array([77.52969], dtype=float32), array([48.409866], dtype=float32), array([79.562164], dtype=float32), array([74.90595], dtype=float32), array([61.3438], dtype=float32), array([48.409866], dtype=float32), array([67.58904], dtype=float32), array([66.29565], dtype=float32), array([4.4344916], dtype=float32), array([57.278847], dtype=float32), array([76.97538], dtype=float32), array([68.06944], dtype=float32), array([70.24973], dtype=float32), array([60.97426], dtype=float32), array([70.10192], dtype=float32), array([64.52185], dtype=float32), array([29.932817], dtype=float32), array([55.061604], dtype=float32), array([70.54537], dtype=float32), array([58.01
array([69.98457], dtype=float32), array([82.1514], dtype=float32), array([41.973], dtype=float32), array([71.304344], dtype=float32), array([71.96624], dtype=float32), array([35.76232], dtype=float32), array([58.612545], dtype=float32), array([82.1514], dtype=float32), array([60.6466], dtype=float32), array([71.27209], dtype=float32), array([36.585396], dtype=float32), array([38.676277], dtype=float32), array([62.136677], dtype=float32), array([68.42145], dtype=float32), array([70.55784], dtype=float32), array([55.66593], dtype=float32), array([82.1514], dtype=float32), array([82.1514], dtype=float32), array([36.459007], dtype=float32), array([82.1514], dtype=float32), array([36.947792], dtype=float32), array([34.389595], dtype=float32), array([70.53104], dtype=float32), array([38.132256], dtype=float32), array([39.47715], dtype=float32), array([39.893524], dtype=float32), array([70.41779], dtype=float32), array([82.1514], dtype=float32), array([66.37025], dtype=float32), array([40.100777], dtype=float32), array([34.465057], dtype=float32), array([42.278294], dtype=float32), array([39.359978], dtype=float32), array([70.77472], dtype=float32), array([70.92312], dtype=float32), array([38.077904], dtype=float32), array([40.071617], dtype=float32), array([58.302467], dtype=float32), array([53.575233], dtype=float32), array([40.270638], dtype=float32), array([82.1514], dtype=float32), array([62.453583], dtype=float32), array([82.1514], dtype=float32), array([52.166786], dtype=float32), array([82.1514], dtype=float32), array([64.16017], dtype=float32), array([65.049385], dtype=float32), array([82.1514], dtype=float32), array([82.1514], dtype=float32), array([56.364395], dtype=float32), array([49.97003], dtype=float32), array([72.94152], dtype=float32), array([82.1514], dtype=float32), array([55.442184], dtype=float32), array([56.682426], dtype=float32), array([80.04272], dtype=float32), array([82.1514], dtype=float32), array([82.1514], dtype=float32), array([41.510902], dtype=float32), array([82.1514], dtype=float32), array([82.1514], dtype=float32), array([36.630196], dtype=float32), array([35.535194], dtype=float32), array([59.321144], dtype=float32), array([65.25693], dtype=float32), array([72.1949], dtype=float32), array([36.832405], dtype=float32), array([37.82348], dtype=float32), array([55.327126], dtype=float32), array([82.1514], dtype=float32), array([35.773277], dtype=float32), array([70.09408], dtype=float32), array([73.37489], dtype=float32), array([55.033577], dtype=float32), array([82.1514], dtype=float32), arra ...

# %%
print(len(b))
# Out:
# 664

# %%
# plotting the graph for a and b
import matplotlib.pyplot as plt
plt.plot(a, label='True labels')
plt.plot(b, label='Predicted labels')
plt.legend()
plt.show()

# %%
# displaying the true and predicted labels in different graphs
import matplotlib.pyplot as plt
plt.plot(a, label='True labels')
plt.legend()
plt.show()

# %%
plt.plot(b, label='Predicted labels')
plt.legend()
plt.show()

# %%
# calculating the mean absolute error
from sklearn.metrics import mean_absolute_error
mean_absolute_error(a,b)
# Out:
# 6.802608

# %%
# calculating the mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(a,b)
# Out:
# 85.94195

# %%
# calculating the root mean squared error
from sklearn.metrics import mean_squared_error
mean_squared_error(a,b, squared=False)
# Out:
# 9.270488

# %%
# calculating the r2 score
from sklearn.metrics import r2_score
r2_score(a,b)
# Out:
# 0.7535068022489532

# %%
# printing the mean absolute percentage error using sklearn
from sklearn.metrics import mean_absolute_percentage_error
mean_absolute_percentage_error(a,b)
# Out:
# 0.224042
